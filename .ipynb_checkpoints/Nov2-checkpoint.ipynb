# %%
import json, urllib
import requests
from bs4 import BeautifulSoup
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', 500)
# %matplotlib inline
import scipy.stats as ss
import numpy as np

# %%
df= pd.read_csv('data_final_project_v3.csv', sep=';', encoding='ISO-8859-1', nrows=2000)
df.head()
# Out:
#    directorio      llave   fex_c ciudad_origen depto_origen mes_recolec  \
# 0     3000000  3000000_1  2629.5      Medellín    Antioquia     FEBRERO
# 1     3000000  3000000_1  2629.5      Medellín    Antioquia     FEBRERO
# 2     3000000  3000000_1  2629.5      Medellín    Antioquia     FEBRERO
# 3     3000001  3000001_1  2256.5      Medellín    Antioquia     FEBRERO
# 4     3000001  3000001_1  2256.5      Medellín    Antioquia     FEBRERO
#
#   trimestre   sexo  edad rango_edad parentesco estado_civ  estrato  \
# 0   PRIMERO  mujer    56      55_60       jefe    soltero        1
# 1   PRIMERO  mujer    25      20_25       hijo    soltero        1
# 2   PRIMERO  mujer     1       0_15      nieto        NaN        1
# 3   PRIMERO  mujer    39      35_40       jefe   separado        1
# 4   PRIMERO  mujer    14       0_15       hijo    soltero        1
#
#    ingreso_hogar rango_ingreso_hog estudia   nivel_edu    diploma       labor  \
# 0         880000               1_2      no    primaria        NaN     ocupado
# 1         880000               1_2      si       media  bachiller  desocupado
# 2         880000               1_2     NaN         NaN        NaN         NaN
# 3         860000               1_2      no  secundaria        NaN     ocupado
# 4         860000               1_2      si  secundaria        NaN    inactivo
#
#   viajo extranjero  cuantos_ext interno  cuantos_int depto_dest  mpio_dest  \
# 0    no        NaN            0     NaN            0        NaN        NaN
# 1    no        NaN            0     NaN            0        NaN        NaN
# 2   NaN        NaN            0     NaN            0        NaN        NaN
# 3    no        NaN            0     NaN            0        NaN        NaN
# 4    no        NaN            0     NaN            0        NaN        NaN
#
#   fecha_ini fecha_fin  pernoct motivo_int depto_mv  mpio_mv tiene_viv  \
# 0       NaN       NaN      NaN        NaN      NaN      NaN        no
# 1       NaN       NaN      NaN        NaN      NaN      NaN        no
# 2       NaN       NaN      NaN        NaN      NaN      NaN        no
# 3       NaN       NaN      NaN        NaN      NaN      NaN        no
# 4       NaN       NaN      NaN        NaN      NaN      NaN        no
#
#   aloj_segviv aloj_hotel aloj_centvac aloj_fami aloj_vivtur med_transp  \
# 0         NaN        NaN          NaN       NaN         NaN        NaN
# 1         NaN        NaN          NaN       NaN         NaN        NaN
# 2         NaN        NaN          NaN       NaN         NaN        NaN
# 3         NaN        NaN          NaN       NaN         NaN        NaN
# 4         NaN        NaN          NaN       NaN         NaN        NaN
#
#   pago_paqtur quien_pago  pers_gasto  cuanto_pago  estim_valor  paqtur_aloj  \
# 0         NaN        NaN         NaN          NaN          NaN          NaN
# 1         NaN        NaN         NaN          NaN          NaN          NaN
# 2         NaN        NaN         NaN          NaN          NaN          NaN
# 3         NaN        NaN         NaN          NaN          NaN          NaN
# 4         NaN        NaN         NaN          NaN          NaN          NaN
#
#    paqtur_transp  paqtur_alim  paqtur_tours  paqtur_segur  paqtur_otros  \
# 0            NaN          NaN           NaN           NaN           NaN
# 1            NaN          NaN           NaN           NaN           NaN
# 2            NaN          NaN           NaN           NaN           NaN
# 3            NaN          NaN           NaN           NaN           NaN
# 4            NaN          NaN           NaN           NaN           NaN
#
#    paqtur_recrea  gasto_tot motivo_no gast_aloj  valgast_aloj  pergast_aloj  \
# 0            NaN        NaN    tiempo       NaN           NaN           NaN
# 1            NaN        NaN  recursos       NaN           NaN           NaN
# 2            NaN        NaN       NaN       NaN           NaN           NaN
# 3            NaN        NaN    tiempo       NaN           NaN           NaN
# 4            NaN        NaN  recursos       NaN           NaN           NaN
#
#   gast_transp  valgast_transp  pergast_transp gast_public  valgast_public  \
# 0         NaN             NaN             NaN         NaN             NaN
# 1         NaN             NaN             NaN         NaN             NaN
# 2         NaN             NaN             NaN         NaN             NaN
# 3         NaN             NaN             NaN         NaN             NaN
# 4         NaN             NaN             NaN         NaN             NaN
#
#    pergast_public gast_alim  valgast_alim  pergast_alim gast_aereo  \
# 0             NaN       NaN           NaN           NaN        NaN
# 1             NaN       NaN           NaN           NaN        NaN
# 2             NaN       NaN           NaN           NaN        NaN
# 3             NaN       NaN           NaN           NaN        NaN
# 4             NaN       NaN           NaN           NaN        NaN
#
#    valgast_aereo  pergast_aereo excursion excur_extranj excur_int excur_motiv  \
# 0            NaN            NaN        no           NaN       NaN         NaN
# 1            NaN            NaN        no           NaN       NaN         NaN
# 2            NaN            NaN       NaN           NaN       NaN         NaN
# 3            NaN            NaN        no           NaN       NaN         NaN
# 4            NaN            NaN        no           NaN       NaN         NaN
#
#    excur_deptodest  excur_mpiodest excur_medtransp  excur_valgasttransp  \
# 0              NaN             NaN             NaN                  NaN
# 1              NaN             NaN             NaN                  NaN
# 2              NaN             NaN             NaN                  NaN
# 3              NaN             NaN             NaN                  NaN
# 4              NaN             NaN             NaN                  NaN
#
#    excur_pergasttransp  excur_valgastpublic  excur_pergastpublic  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4                  NaN                  NaN                  NaN
#
#    excur_valgastalim  excur_pergastalim  Unnamed: 81
# 0                NaN                NaN          NaN
# 1                NaN                NaN          NaN
# 2                NaN                NaN          NaN
# 3                NaN                NaN          NaN
# 4                NaN                NaN          NaN

# %%
def tipo(x):
    if x['edad'].count() < 2:
        return x['sexo'][0]
    else:
        return "familia"

def rango_edad(x):
    mediana=np.floor(x['edad'].median()) 
    if mediana > 80:
        return "80_"
    elif mediana >= 75:
        return '75_80'
    elif mediana >= 70:
        return '70_75'
    elif mediana >= 65:
        return '65_70'
    elif mediana >= 60:
        return '60_65'
    elif mediana >= 55:
        return '55_60'
    elif mediana >= 50:
        return '50_55'
    elif mediana >= 45:
        return '45_50'
    elif mediana >= 40:
        return '40_45'
    elif mediana >= 35:
        return '35_40'
    elif mediana >= 30:
        return '30_35'
    elif mediana >= 25:
        return '25_30'
    elif mediana >= 20:
        return '20_25'
    elif mediana >= 15:
        return '15_20'
    elif mediana >= 10:
        return '10_15'
    else:
        return '0_10'
        
def estado_civil(x):
    if x['edad'].count() < 2:
        return x['estado_civ'][0]
    else:
        return "familia"

def alojamiento(x):
    if 'si' in x['aloj_hotel']:
        return 'hotel'
    elif 'si' in x['aloj_centvac']:
        return 'centro_vac'
    elif 'si' in x['aloj_vivtur']:
        return 'vivienda_tur'
    elif 'si' in x['aloj_segviv']:
        return 'segunda_viv'
    elif 'si' in x['aloj_fami']:
        return 'casa_familia'
    else:
        return None

def educacion(x):
    if 'superior' in x['nivel_edu'].tolist() and 'posgrado' in x['diploma'].tolist():
        return "superior_posgrado"
    elif 'superior' in x['nivel_edu'].tolist() and 'universitario' in x['diploma'].tolist():
        return "superior_univerisitario"
    elif 'superior' in x['nivel_edu'].tolist() and 'tecnico' in x['diploma'].tolist():
        return "superior_tecnico"
    elif 'superior' in x['nivel_edu'].tolist() and 'bachiller' in x['diploma'].tolist():
        return "superior_bachiller"
    elif 'superior' in x['nivel_edu'].tolist() and 'ninguno' in x['diploma'].tolist():
        return "superior"
    elif 'superior' in x['nivel_edu'].tolist() and 'no_informa' in x['diploma'].tolist():
        return "superior"
    elif 'media' in x['nivel_edu'].tolist() and 'bachiller' in x['diploma'].tolist():
        return "media_bachiller"
    elif 'media' in x['nivel_edu'].tolist() and 'ninguno' in x['diploma'].tolist():
        return "media"
    elif 'media' in x['nivel_edu'].tolist() and 'no_informa' in x['diploma'].tolist():
        return "media"
    else:
        return x['nivel_edu'][0]

# %%
df_familia=df.groupby('llave').apply(lambda x : pd.Series({
    'cant_indiv':x['edad'].count(),
    'coef':ss.variation(x["edad"]),
    'ciudad_origen':x['ciudad_origen'][0],
    'tipo':tipo(x),
    'edad_mediana':np.floor(x['edad'].median()),
    'rango_edad':rango_edad(x),
    'estrato':x['estrato'][0],
    'ingreso_hogar': x['ingreso_hogar'].mean(),
    'rango_ingreso_hog': x['rango_ingreso_hog'][0],
    'estado_civ': estado_civil(x),
    'nivel_edu':educacion(x),
    'viajo': x['viajo'][0],
    'interno':x['interno'][0],    
#     
    'cuantos_int':  x['cuantos_int'][0],
    'depto_dest': x['depto_dest'][0],
    'mpio_dest': x['mpio_dest'][0],
    'fecha_ini': x['fecha_ini'][0],
    'fecha_fin': x['fecha_fin'][0],
    'pernoct': x['pernoct'][0],
    'motivo_int': x['motivo_int'][0],   
    'alojamiento': alojamiento(x),
    'med_transp': x['med_transp'][0],
    'gasto_tot': x['gasto_tot'][0],
    'motivo_no':x['motivo_no'][0],
    'gast_aloj':x['gast_aloj'][0],
    'valgast_aloj':x['valgast_aloj'][0],
    'gast_public':x['gast_public'][0],
    'valgast_public':x['valgast_public'][0],
    'gast_alim':x['gast_alim'][0],
    'gast_aereo':x['gast_aereo'][0],
    'valgast_aereo':x['valgast_aereo'][0],
    'excursion':x['excursion'][0],
    'excur_extranj':x['excur_extranj'][0],
    'excur_int':x['excur_int'][0],
    'excur_motiv':x['excur_motiv'][0],
    'excur_deptodest':x['excur_deptodest'][0],
    'excur_mpiodest':x['excur_mpiodest'][0],
    'excur_medtransp':x['excur_medtransp'][0],
    'excur_valgasttransp':x['excur_valgasttransp'][0],
    'excur_valgastpublic':x['excur_valgastpublic'][0],
    'excur_valgastalim':x['excur_valgastalim'][0]    
}))

# %%
df_familia
# Out:
#            cant_indiv      coef ciudad_origen     tipo  edad_mediana  \
# llave
# 3000000_1           3  0.823690      Medellín  familia          25.0
# 3000001_1           3  0.635001      Medellín  familia          14.0
# 3000002_1           1  0.000000      Medellín    mujer          68.0
# 3000003_1           3  0.593015      Medellín  familia          21.0
# 3000004_1           4  0.435135      Medellín  familia          19.0
# ...               ...       ...           ...      ...           ...
# 3000586_1           3  0.756746          Cali  familia          22.0
# 3000587_1           4  0.445086          Cali  familia          39.0
# 3000588_1           5  0.661747          Cali  familia          19.0
# 3000589_1           5  0.655262          Cali  familia          17.0
# 3000590_1           2  0.152542          Cali  familia          29.0
#
#           rango_edad  estrato  ingreso_hogar rango_ingreso_hog estado_civ  \
# llave
# 3000000_1      25_30        1       880000.0               1_2    familia
# 3000001_1      10_15        1       860000.0               1_2    familia
# 3000002_1      65_70        1      1050000.0               1_2      viudo
# 3000003_1      20_25        1       820000.0               0_1    familia
# 3000004_1      15_20        1       850000.0               1_2    familia
# ...              ...      ...            ...               ...        ...
# 3000586_1      20_25        2       800000.0               0_1    familia
# 3000587_1      35_40        2      3000000.0               3_5    familia
# 3000588_1      15_20        2      2000000.0               2_3    familia
# 3000589_1      15_20        2       828000.0               0_1    familia
# 3000590_1      25_30        2      1000000.0               1_2    familia
#
#                          nivel_edu viajo interno  cuantos_int depto_dest  \
# llave
# 3000000_1          media_bachiller    no     NaN            0        NaN
# 3000001_1               secundaria    no     NaN            0        NaN
# 3000002_1                 primaria    no     NaN            0        NaN
# 3000003_1          media_bachiller    no     NaN            0        NaN
# 3000004_1          media_bachiller    no     NaN            0        NaN
# ...                            ...   ...     ...          ...        ...
# 3000586_1                    media    no     NaN            0        NaN
# 3000587_1         superior_tecnico    no     NaN            0        NaN
# 3000588_1  superior_univerisitario    no     NaN            0        NaN
# 3000589_1          media_bachiller    no     NaN            0        NaN
# 3000590_1  superior_univerisitario    no     NaN            0        NaN
#
#            mpio_dest fecha_ini fecha_fin  pernoct motivo_int alojamiento  \
# llave
# 3000000_1        NaN       NaN       NaN      NaN        NaN        None
# 3000001_1        NaN       NaN       NaN      NaN        NaN        None
# 3000002_1        NaN       NaN       NaN      NaN        NaN        None
# 3000003_1        NaN       NaN       NaN      NaN        NaN        None
# 3000004_1        NaN       NaN       NaN      NaN        NaN        None
# ...              ...       ...       ...      ...        ...         ...
# 3000586_1        NaN       NaN       NaN      NaN        NaN        None
# 3000587_1        NaN       NaN       NaN      NaN        NaN        None
# 3000588_1        NaN       NaN       NaN      NaN        NaN        None
# 3000589_1        NaN       NaN       NaN      NaN        NaN        None
# 3000590_1        NaN       NaN       NaN      NaN        NaN        None
#
#           med_transp  gasto_tot motivo_no gast_aloj  valgast_aloj gast_public  \
# llave
# 3000000_1        NaN        NaN    tiempo       NaN           NaN         NaN
# 3000001_1        NaN        NaN    tiempo       NaN           NaN         NaN
# 3000002_1        NaN        NaN  recursos       NaN           NaN         NaN
# 3000003_1        NaN        NaN  recursos       NaN           NaN         NaN
# 3000004_1        NaN        NaN  recursos       NaN           NaN         NaN
# ...              ...        ...       ...       ...           ...         ...
# 3000586_1        NaN        NaN  recursos       NaN           NaN         NaN
# 3000587_1        NaN        NaN  recursos       NaN           NaN         NaN
# 3000588_1        NaN        NaN  recursos       NaN           NaN         NaN
# 3000589_1        NaN        NaN  recursos       NaN           NaN         NaN
# 3000590_1        NaN        NaN  recursos       NaN           NaN         NaN
#
#            valgast_public gast_alim gast_aereo  valgast_aereo excursion  \
# llave
# 3000000_1             NaN       NaN        NaN            NaN        no
# 3000001_1             NaN       NaN        NaN            NaN        no
# 3000002_1             NaN       NaN        NaN            NaN        no
# 3000003_1             NaN       NaN        NaN            NaN        no
# 3000004_1             NaN       NaN        NaN            NaN        no
# ...                   ...       ...        ...            ...       ...
# 3000586_1             NaN       NaN        NaN            NaN        no
# 3000587_1             NaN       NaN        NaN            NaN        no
# 3000588_1             NaN       NaN        NaN            NaN        no
# 3000589_1             NaN       NaN        NaN            NaN        si
# 3000590_1             NaN       NaN        NaN            NaN        si
#
#           excur_extranj excur_int excur_motiv  excur_deptodest  \
# llave
# 3000000_1           NaN       NaN         NaN              NaN
# 3000001_1           NaN       NaN         NaN              NaN
# 3000002_1           NaN       NaN         NaN              NaN
# 3000003_1           NaN       NaN         NaN              NaN
# 3000004_1           NaN       NaN         NaN              NaN
# ...                 ...       ...         ...              ...
# 3000586_1           NaN       NaN         NaN              NaN
# 3000587_1           NaN       NaN         NaN              NaN
# 3000588_1           NaN       NaN         NaN              NaN
# 3000589_1            no        si    Negocios             76.0
# 3000590_1            no        si  Vacaciones             76.0
#
#            excur_mpiodest       excur_medtransp  excur_valgasttransp  \
# llave
# 3000000_1             NaN                   NaN                  NaN
# 3000001_1             NaN                   NaN                  NaN
# 3000002_1             NaN                   NaN                  NaN
# 3000003_1             NaN                   NaN                  NaN
# 3000004_1             NaN                   NaN                  NaN
# ...                   ...                   ...                  ...
# 3000586_1             NaN                   NaN                  NaN
# 3000587_1             NaN                   NaN                  NaN
# 3000588_1             NaN                   NaN                  NaN
# 3000589_1         76520.0     Terrestre publico               6400.0
# 3000590_1         76520.0  Terrestre particular                  NaN
#
#            excur_valgastpublic  excur_valgastalim
# llave
# 3000000_1                  NaN                NaN
# 3000001_1                  NaN                NaN
# 3000002_1                  NaN                NaN
# 3000003_1                  NaN                NaN
# 3000004_1                  NaN                NaN
# ...                        ...                ...
# 3000586_1                  NaN                NaN
# 3000587_1                  NaN                NaN
# 3000588_1                  NaN                NaN
# 3000589_1                  NaN             1000.0
# 3000590_1                  NaN            50000.0
#
# [588 rows x 41 columns]

# %%
df['nivel_edu'].unique()
# Out:
# array(['primaria', 'media', nan, 'secundaria', 'preescolar', 'superior',
#        'ninguno', 'no_informa'], dtype=object)
